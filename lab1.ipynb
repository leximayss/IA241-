# %%
1+3
# Out:
# 4

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## q1

# %% [markdown]
# 1. item1
# 2. item2

# %% [markdown]
# [jmu](http://www.jmu.edu)

# %%
a = 3
b = 4
a+b
# Out:
# 7

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

plt.plot(X, C)
plt.plot(X, S)

plt.show()
